# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfscore = pd.read_csv('./data/sql_sc.csv')

# %%
dfscore
# Out:
#     Sn Name  Percentage
# 0    1    J        85.0
# 1    2    W        63.0
# 2    3    S        98.0
# 3    4    S        98.0
# 4    5    D       100.0
# 5    6    K       100.0
# 6    7    I        89.0
# 7    8    J        90.0
# 8    9    M        55.0
# 9   10    B        78.0
# 10  11    F        83.0
# 11  12    M        90.0
# 12  13    C        93.0
# 13  14    A        93.0
# 14  15    C        95.0
# 15  16    J        93.0
# 16  17    K        93.0
# 17  18    O        98.0
# 18  19    Y        73.0
# 19  20    D        90.0
# 20  21    S        50.0
# 21  22    A        93.0
# 22  23    M        90.0
# 23  24    B        93.0
# 24  25    B        95.0
# 25  26    T        95.0
# 26  27    H        95.0
# 27  28    A        85.0
# 28  29    S        93.0
# 29  30    A        93.0
# 30  31    N        90.0
# 31  32    A        95.0
# 32  33    C        90.0
# 33  34    F        90.0
# 34  35    C        85.0
# 35  36    D        90.0
# 36  37    K        75.0
# ...

# %%
dfscore['Percentage'].isnull().sum()
dfscore.to_excel()
# Out:
# 1

# %%
plt.scatter(dfscore['Name'], dfscore['Percentage'])
plt.show()

# %%
dfscore.fillna(15)
# Out:
#     Sn Name  Percentage
# 0    1    J        85.0
# 1    2    W        63.0
# 2    3    S        98.0
# 3    4    S        98.0
# 4    5    D       100.0
# 5    6    K       100.0
# 6    7    I        89.0
# 7    8    J        90.0
# 8    9    M        55.0
# 9   10    B        78.0
# 10  11    F        83.0
# 11  12    M        90.0
# 12  13    C        93.0
# 13  14    A        93.0
# 14  15    C        95.0
# 15  16    J        93.0
# 16  17    K        93.0
# 17  18    O        98.0
# 18  19    Y        73.0
# 19  20    D        90.0
# 20  21    S        50.0
# 21  22    A        93.0
# 22  23    M        90.0
# 23  24    B        93.0
# 24  25    B        95.0
# 25  26    T        95.0
# 26  27    H        95.0
# 27  28    A        85.0
# 28  29    S        93.0
# 29  30    A        93.0
# 30  31    N        90.0
# 31  32    A        95.0
# 32  33    C        90.0
# 33  34    F        90.0
# 34  35    C        85.0
# 35  36    D        90.0
# 36  37    K        75.0
# ...

# %%
plt.hist(dfscore['Percentage'])
plt.show()

# %%
dfscore.describe().T
# Out:
#             count       mean        std   min    25%   50%    75%    max
# Sn           56.0  28.500000  16.309506   1.0  14.75  28.5  42.25   56.0
# Percentage   55.0  88.254545  10.254571  50.0  85.00  90.0  95.00  100.0

# %%
plt.boxplot(dfscore['Percentage'])
#plt.show()
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f696a02560>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f696a02aa0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f696a022c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f696a02fe0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f696a03280>],
#  'means': []}

# %%
df_iris = pd.read_csv('./data/iris.csv')

# %%
df_iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df_iris.head(15)
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# ...

# %%
df_iris['variety']
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: variety, Length: 150, dtype: object

# %%
plt.boxplot(df_iris['sepal.width'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f691a741f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f691a74730>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f696c0ffd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f696c02230>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f696b85330>],
#  'means': []}
